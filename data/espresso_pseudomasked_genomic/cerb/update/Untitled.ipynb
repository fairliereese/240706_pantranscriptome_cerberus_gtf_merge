# %%
import  cerberus
import glob
import pyranges as pr
import pandas as pd

# %%
df = pd.DataFrame()
for f in glob.glob('*gtf'):
    df = pd.concat([pr.read_gtf(f, as_df=True), df], axis=0)
    break

# %%
temp = df.loc[df.Feature=='transcript']
temp.loc[temp.transcript_id.duplicated(keep=False)].sort_values(by='transcript_id')
# Out:
#        Chromosome Source     Feature     Start       End Score Strand Frame  \
# 114    GL000195.1    NaN  transcript     48901     86687     .      -     .
# 227    GL000205.2    NaN  transcript    137791    145075     .      -     .
# 282    GL000219.1    NaN  transcript     98559     99612     .      +     .
# 11357        chr1    NaN  transcript  70205727  70208101     .      +     .
# 11360        chr1    NaN  transcript  70205732  70215360     .      +     .
#
#       gene_id   ic  ...  tss tes_id  tes transcript_id transcript_name  \
# 114        NA  NaN  ...  NaN    NaN  NaN           NaN             NaN
# 227        NA  NaN  ...  NaN    NaN  NaN           NaN             NaN
# 282        NA  NaN  ...  NaN    NaN  NaN           NaN             NaN
# 11357      NA  NaN  ...  NaN    NaN  NaN           NaN             NaN
# 11360      NA  NaN  ...  NaN    NaN  NaN           NaN             NaN
#
#       gene_name tes_last_sa_issue original_transcript_id  \
# 114         NaN               NaN                    NaN
# 227         NaN               NaN                    NaN
# 282         NaN               NaN                    NaN
# 11357       NaN               NaN                    NaN
# 11360       NaN               NaN                    NaN
#
#       original_transcript_name tss_first_sd_issue
# 114                        NaN                NaN
# 227                        NaN                NaN
# 282                        NaN                NaN
# 11357                      NaN                NaN
# 11360                      NaN                NaN
#
# [5 rows x 22 columns]

# %%
df = cerberus.sort_gtf(df)

# %%
print(len(df.index))
df = cerberus.agg_gtf(df)
print(len(df.index))
# Out:
# 401447
# 399412

# %%
# duplicated genes?
temp = df.loc[df.Feature=='gene']
temp.loc[temp.gene_id.duplicated(keep=False)].sort_values(by='gene_id').head()
assert len(temp.loc[temp.gene_id.duplicated()].index) == 0

# %%
# duplicated transcripts?
temp = df.loc[df.Feature=='transcript']
temp.loc[temp.transcript_id.duplicated(keep=False)].sort_values(by='transcript_id')
# assert len(temp.loc[temp.transcript_id.duplicated()].index) == 0
# Out:
#        Chromosome     Feature      Start        End Score Strand Frame  \
# 199754       chrX  transcript  100627097  100636831     .      -     .
# 199753       chrX  transcript  100627097  100636831     .      -     .
# 0            chr1  transcript  169795014  169804357     .      +     .
# 1            chr1  transcript  169795014  169804357     .      +     .
# 199828       chr1  transcript   27612281   27626265     .      -     .
# ...           ...         ...        ...        ...   ...    ...   ...
# 395602       chr9  transcript      24329      25007     .      -     .
# 395603       chr9  transcript      24329      25007     .      -     .
# 395604       chr9  transcript      24328      25007     .      -     .
# 395605       chr9  transcript      23296      25007     .      -     .
# 395606       chr9  transcript      20189      25007     .      -     .
#
#                    gene_id   ic              ic_id  ...             tes_id  \
# 199754  ENSG00000000003.16  1.0  ENSG00000000003_1  ...  ENSG00000000003_1
# 199753  ENSG00000000003.16  1.0  ENSG00000000003_1  ...  ENSG00000000003_1
# 0       ENSG00000000460.17  4.0  ENSG00000000460_4  ...  ENSG00000000460_2
# 1       ENSG00000000460.17  4.0  ENSG00000000460_4  ...  ENSG00000000460_2
# 199828  ENSG00000000938.13  3.0  ENSG00000000938_3  ...  ENSG00000000938_2
# ...                    ...  ...                ...  ...                ...
# 395602                  NA  NaN                NaN  ...                NaN
# 395603                  NA  NaN                NaN  ...                NaN
# 395604                  NA  NaN                NaN  ...                NaN
# 395605                  NA  NaN                NaN  ...                NaN
# 395606                  NA  NaN                NaN  ...                NaN
#
#         tes           transcript_id         transcript_name        gene_name  \
# 199754  1.0  ENSG00000000003[1,1,1]  ENSG00000000003[1,1,1]  ENSG00000000003
# 199753  1.0  ENSG00000000003[1,1,1]  ENSG00000000003[1,1,1]  ENSG00000000003
# 0       2.0  ENSG00000000460[1,4,2]  ENSG00000000460[1,4,2]  ENSG00000000460
# 1       2.0  ENSG00000000460[1,4,2]  ENSG00000000460[1,4,2]  ENSG00000000460
# 199828  2.0  ENSG00000000938[3,3,2]  ENSG00000000938[3,3,2]  ENSG00000000938
# ...     ...                     ...                     ...              ...
# 395602  NaN                     NaN                     NaN              NaN
# 395603  NaN                     NaN                     NaN              NaN
# 395604  NaN                     NaN                     NaN              NaN
# 395605  NaN                     NaN                     NaN              NaN
# 395606  NaN                     NaN                     NaN              NaN
#
#        tes_last_sa_issue             Source original_transcript_name  \
# 199754             False  annotated_isoform        ENST00000373020.9
# 199753             False  annotated_isoform        ENST00000373020.9
# 0                  False  annotated_isoform        ENST00000496973.5
# 1                  False  annotated_isoform        ENST00000496973.5
# 199828             False  annotated_isoform        ENST00000399173.5
# ...                  ...                ...                      ...
# 395602               NaN                NaN                      NaN
# 395603               NaN                NaN                      NaN
# 395604               NaN                NaN                      NaN
# 395605               NaN                NaN                      NaN
# 395606               NaN                NaN                      NaN
#
#        tss_first_sd_issue original_transcript_id
# 199754              False      ENST00000373020.9
# 199753              False      ENST00000373020.9
# 0                   False      ENST00000496973.5
# 1                   False      ENST00000496973.5
# 199828              False      ENST00000399173.5
# ...                   ...                    ...
# 395602                NaN                    NaN
# 395603                NaN                    NaN
# 395604                NaN                    NaN
# 395605                NaN                    NaN
# 395606                NaN                    NaN
#
# [48156 rows x 22 columns]

# %%
gb_cols = ['Chromosome',
                 'Feature',
                 'Start', 'End',
                 'Score', 'Strand', 'Frame', 'gene_id', 'gene_name',
                 'gene_status', 'gene_type', 'talon_gene',
                 'ic', 'ic_id', 'tss_id', 'tss', 'tes_id', 'tes', 'transcript_id',
                 'transcript_name']
gb_cols = list(set(temp.columns)&set(gb_cols))

# %%
temp = temp[gb_cols]
print(len(temp.index))
temp.drop_duplicates(inplace=True)
print(len(temp.index))
# Out:
# 67390
# 44489

# %%
def collapse_non_gb_col(x):
    x = x.fillna('')
    x = x.astype(str)
    x = x.unique().tolist()
    x = ','.join(x)
    if x == '':
        x = np.nan
    return(x)

gb_cols = ['Chromosome',
             'Feature',
             'Start', 'End',
             'Score', 'Strand', 'Frame', 'gene_id', 'gene_name',
             'gene_status', 'gene_type', 'talon_gene',
             'ic', 'ic_id', 'tss_id', 'tss', 'tes_id', 'tes', 'transcript_id',
             'transcript_name']
gb_cols = list(set(df.columns)&set(gb_cols))

# get dictionary:function mapping for aggregation
agg_cols = list(set(df.columns)-set(gb_cols))
agg_dict = dict()
for c in agg_cols:
    agg_dict[c] = collapse_non_gb_col

# get collapsed features to add to deduplicated df
t_df = df.loc[df.Feature == 'transcript'].copy(deep=True)

non_gb_cols = list(set(t_df.columns.tolist())-set(gb_cols))
t_df[non_gb_cols].fillna('', inplace=True)
t_df = t_df.groupby(gb_cols, observed=True).agg(agg_dict).reset_index()
t_df = t_df[['transcript_id']+non_gb_cols]
collapsed_feats = t_df.copy(deep=True)

# # replace the non gb columns with the ones that we already grouped
# df.drop(non_gb_cols, axis=1, inplace=True)
# df = df.merge(collapsed_feats, how='left', on='transcript_id'

# %%
print(len(t_df.index))
print(len(t_df.transcript_id.unique()))
t_df.head()
# Out:
# 42103
# 42103
#               transcript_id             Source tes_last_sa_issue  \
# 0    ENSG00000000003[1,1,1]  annotated_isoform             False
# 1    ENSG00000000419[1,1,1]  annotated_isoform             False
# 2  ENSG00000000419[1,10,10]  annotated_isoform             False
# 3    ENSG00000000457[1,1,1]  annotated_isoform             False
# 4    ENSG00000000457[3,3,2]  annotated_isoform             False
#
#   original_transcript_name tss_first_sd_issue original_transcript_id
# 0        ENST00000373020.9              False      ENST00000373020.9
# 1       ENST00000371588.10              False     ENST00000371588.10
# 2        ENST00000684628.1              False      ENST00000684628.1
# 3       ENST00000367771.11              False     ENST00000367771.11
# 4        ENST00000367772.8              False      ENST00000367772.8

# %%
print(len(collapsed_feats.index))
print(len(collapsed_feats.transcript_id.unique()))
collapsed_feats.head()
# Out:
# 42103
# 42103
#               transcript_id             Source tes_last_sa_issue  \
# 0    ENSG00000000003[1,1,1]  annotated_isoform             False
# 1    ENSG00000000419[1,1,1]  annotated_isoform             False
# 2  ENSG00000000419[1,10,10]  annotated_isoform             False
# 3    ENSG00000000457[1,1,1]  annotated_isoform             False
# 4    ENSG00000000457[3,3,2]  annotated_isoform             False
#
#   original_transcript_name tss_first_sd_issue original_transcript_id
# 0        ENST00000373020.9              False      ENST00000373020.9
# 1       ENST00000371588.10              False     ENST00000371588.10
# 2        ENST00000684628.1              False      ENST00000684628.1
# 3       ENST00000367771.11              False     ENST00000367771.11
# 4        ENST00000367772.8              False      ENST00000367772.8

# %%
# deduplicate df based only on transcript id
temp = df[['transcript_id', 'original_transcript_id']].drop_duplicates()
print(len(temp.index))
dupe_old_tids = temp.loc[temp.transcript_id.duplicated(keep='first'), 'original_transcript_id']
df = df.loc[~df.original_transcript_id.isin(dupe_old_tids)]
# Out:
# 42104

# %%
temp.loc[temp.transcript_id.duplicated()].head()
# Out:
# Empty DataFrame
# Columns: [transcript_id, original_transcript_id]
# Index: []

# %%
# temp2 = temp[['transcript_id', 'original_transcript_id']].merge(t_df[['transcript_id', 'original_transcript_id', 'Source']],
#                                                                 how='outer', on=['transcript_id', 'original_transcript_id'])

# %%
# temp2.loc[temp2.Source.isnull()]
