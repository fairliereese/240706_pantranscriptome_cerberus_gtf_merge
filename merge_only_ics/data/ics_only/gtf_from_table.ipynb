# %%
import cerberus
import pandas as pd

# %%
df = pd.read_csv('merged_smol.gtf', sep='\t')

# %%
# give everything a unique tid
df['tid'] = ['transcript_'+str(i) for i in range(len(df.index))]
df
# Out:
#     Chromosome Strand                                                 ic  \
# 0   GL000008.2      +   83545-83859-84014-85566-85625-88635-88695-129984
# 1   GL000008.2      +   83545-83926-84014-85442-85477-85566-85625-199427
# 2   GL000008.2      +  83545-83926-84014-85456-85477-85566-85625-1351...
# 3   GL000008.2      +   83545-83926-84014-85456-85477-85566-85625-173515
# 4   GL000008.2      +    83545-83926-84014-85456-85477-85566-85625-88635
# 5   GL000008.2      +               83545-83926-84014-85566-85625-129984
# 6   GL000008.2      +  83545-83926-84014-85566-85625-155429-155531-15...
# 7   GL000008.2      +               83545-83926-84014-85566-85625-173515
# 8   GL000008.2      +  83545-83926-84014-85566-85625-173515-173643-19...
# 9         chrY      -                    3218694-3187915-3187827-3185395
# 10        chrY      -                    3219255-3187915-3187827-3185395
# 11        chrY      -    3219255-3188384-3188223-3187915-3187827-3185395
# 12        chrY      -                                    3220633-3220532
# 13        chrY      -  341306-340940-340764-338896-338777-338710-3386...
# 14        chrY      -  386367-361590-361404-347693-347589-347336-3472...
# 15        chrY      -                                  57203181-57202020
# 16        chrY      -                                  57203181-57202145
# 17        chrY      -                                    7076386-7067885
# 18        chrY      -                                      965270-964752
#
#          tss       tes                                             source  \
# 0      83369    130597                    iq_GM22305_1,espresso_GM22305_1
# 1      83374    199914                          iq_HG01567_1,iq_GM22234_1
# 2      83408    157165                    iq_GM22234_1,espresso_GM22234_1
# 3      83391    173639                                 espresso_HG01567_1
# 4      83350     88839                                       iq_GM22234_1
# 5      83378    130204                                 espresso_HG03732_1
# 6      83381    157165  iq_GM22234_1,iq_HG03732_1,espresso_GM22234_1,e...
# 7      83375    175317                                 espresso_GM22234_1
# 8      83378    199914                                       iq_GM22234_1
# 9    3218774   3184977  iq_HG02261_1,iq_GM19390_1,espresso_HG02261_1,e...
# 10   3219354   3183726                                       iq_HG02261_1
# 11   3219345   3185008              espresso_GM22299_1,espresso_HG03732_1
# 12   3220710   3218571              espresso_HG02261_1,espresso_GM18486_1
# 13    341710    334234             iq_HG03729_1,iq_GM12829_1,iq_HG01928_1
# 14    386906    333932                          iq_GM22300_1,iq_GM19352_1
# 15  57203404  57201134                                       iq_HG03729_1
# 16  57203397  57201134             iq_HG04217_1,iq_HG03729_1,iq_HG02293_1
# 17   7076490   7067600                                 espresso_HG02261_1
# 18    965366    964423                                       iq_HG01975_1
#
#               tid
# 0    transcript_0
# 1    transcript_1
# 2    transcript_2
# 3    transcript_3
# 4    transcript_4
# 5    transcript_5
# 6    transcript_6
# 7    transcript_7
# 8    transcript_8
# 9    transcript_9
# 10  transcript_10
# 11  transcript_11
# 12  transcript_12
# 13  transcript_13
# 14  transcript_14
# 15  transcript_15
# 16  transcript_16
# 17  transcript_17
# 18  transcript_18

# %%
# data = {
#     "Chromosome": ["chr"],
#     "Strand": ["+"],
#     "ic": ["2-3-7-10"],
#     "tid": 'test',
#     "tss": [1],
#     "tes": [15],
#     "source": ["source_x"]
# }

# df = pd.DataFrame(data)

# %%
df.tail()
# Out:
#    Chromosome Strand                                                 ic  \
# 14       chrY      -  386367-361590-361404-347693-347589-347336-3472...
# 15       chrY      -                                  57203181-57202020
# 16       chrY      -                                  57203181-57202145
# 17       chrY      -                                    7076386-7067885
# 18       chrY      -                                      965270-964752
#
#          tss       tes                                  source            tid
# 14    386906    333932               iq_GM22300_1,iq_GM19352_1  transcript_14
# 15  57203404  57201134                            iq_HG03729_1  transcript_15
# 16  57203397  57201134  iq_HG04217_1,iq_HG03729_1,iq_HG02293_1  transcript_16
# 17   7076490   7067600                      espresso_HG02261_1  transcript_17
# 18    965366    964423                            iq_HG01975_1  transcript_18

# %%
def process_table_to_gtf_df(df):
    gtf_entries = []

    for index, row in df.iterrows():
        chrom = row['Chromosome']
        strand = row['Strand']
        ic_list = list(map(int, row['ic'].split('-')))
        tss = int(row['tss'])
        tes = int(row['tes'])
        source = row['source']
        gene_id = f"gene_{index}"
        transcript_id = f"transcript_{index}"

        # Define exons based on strand
        if strand == '+':
            exon_coords = [(tss, ic_list[0])]  # First exon
            for i in range(1, len(ic_list) - 1, 2):
                exon_coords.append((ic_list[i], ic_list[i + 1]))  # Middle exons
            exon_coords.append((ic_list[-1], tes))  # Last exon
        else:  # Reverse strand '-'
            exon_coords = [(tes, ic_list[-1])]  # First exon (on reverse strand)
            for i in range(len(ic_list) - 2, 0, -2):
                exon_coords.append((ic_list[i + 1], ic_list[i]))  # Middle exons
            exon_coords.append((ic_list[0], tss))  # Last exon (on reverse strand)

        # Ensure each exon has start < end and create GTF entries
        for i, (start, end) in enumerate(exon_coords):
            start, end = min(start, end), max(start, end)
            attributes = f'gene_id "{gene_id}"; transcript_id "{transcript_id}"; exon_number "{i+1}";'
            gtf_entries.append([chrom, source, 'exon', start, end, '.', strand, '.', attributes])

    # Convert the list of GTF entries to a DataFrame
    gtf_df = pd.DataFrame(gtf_entries, columns=['Chromosome', 'Source', 'Feature', 'Start', 'End', 'Score', 'Strand', 'Frame', 'Attributes'])
    
    return gtf_df

# %%
gtf_df = process_table_to_gtf_df(df)

# %%
gtf_df.loc[gtf_df.Attributes.str.contains('transcript_0')]
# Out:
#    Chromosome                           Source Feature   Start     End Score  \
# 0  GL000008.2  iq_GM22305_1,espresso_GM22305_1    exon   83369   83545     .
# 1  GL000008.2  iq_GM22305_1,espresso_GM22305_1    exon   83859   84014     .
# 2  GL000008.2  iq_GM22305_1,espresso_GM22305_1    exon   85566   85625     .
# 3  GL000008.2  iq_GM22305_1,espresso_GM22305_1    exon   88635   88695     .
# 4  GL000008.2  iq_GM22305_1,espresso_GM22305_1    exon  129984  130597     .
#
#   Strand Frame                                         Attributes
# 0      +     .  gene_id "gene_0"; transcript_id "transcript_0"...
# 1      +     .  gene_id "gene_0"; transcript_id "transcript_0"...
# 2      +     .  gene_id "gene_0"; transcript_id "transcript_0"...
# 3      +     .  gene_id "gene_0"; transcript_id "transcript_0"...
# 4      +     .  gene_id "gene_0"; transcript_id "transcript_0"...

# %%
df.loc[df.tid=='transcript_0']
# Out:
#    Chromosome Strand                                                ic    tss  \
# 0  GL000008.2      +  83545-83859-84014-85566-85625-88635-88695-129984  83369
#
#       tes                           source           tid
# 0  130597  iq_GM22305_1,espresso_GM22305_1  transcript_0

# %%
gtf_df.loc[gtf_df.Attributes.str.contains('transcript_17')]
# Out:
#    Chromosome              Source Feature    Start      End Score Strand  \
# 79       chrY  espresso_HG02261_1    exon  7067600  7067885     .      -
# 80       chrY  espresso_HG02261_1    exon  7076386  7076490     .      -
#
#    Frame                                         Attributes
# 79     .  gene_id "gene_17"; transcript_id "transcript_1...
# 80     .  gene_id "gene_17"; transcript_id "transcript_1...

# %%
df.loc[df.tid=='transcript_17']
# Out:
#    Chromosome Strand               ic      tss      tes              source  \
# 17       chrY      -  7076386-7067885  7076490  7067600  espresso_HG02261_1
#
#               tid
# 17  transcript_17
